# %% [markdown]
# <span style="font-family: 'calibri' ; font-weight: bold; font-size: 24pt;">TOP 15 ACTIVITES USING CHATGPT IN GOOGLE SHEETS</span>.

# %% [markdown]
# <span style="font-family: Calibri; font-size: 18pt;">Integrating ChatGPT with Google Sheets can enable data-driven conversations and enhance the conversational experience by accessing and utilizing data stored in spreadsheets. By leveraging the Google Sheets API and combining it with the conversational abilities of ChatGPT, you can retrieve data from sheets and incorporate it into the generated responses.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-size: 18pt;">ChatGPT is a language model developed by OpenAI, specifically based on the GPT-3.5 architecture.It is designed to generate human-like text responses and engage in conversation with users.ChatGPT has been trained on a vast amount of diverse text data from the internet, enabling it to understand and generate coherent responses across various topics.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-size: 18pt;">This  model uses a transformer neural network architecture, which allows it to capture long-range dependencies and generate contextually appropriate responses. It employs a combination of unsupervised learning and reinforcement learning techniques during training to improve its performance.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-size: 18pt;">OpenAI encourages responsible and ethical use of ChatGPT and provides guidelines for developers to mitigate risks and ensure safe deployment of AI models.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-size: 18pt;">Google Sheets is the primary source of data gathering and collection for many businesses. Most of them use it to perform calculations, clean data, create graphs, and more. But all this takes time when you do it manually.</span>

# %% [markdown]
# <span style="font-family: 'calibri' ; font-weight: bold; font-size: 24pt;">SET UP</span>.

# %% [markdown]
# <span style="font-family: 'calibri' ; font-weight: bold; font-size: 24pt;">1.HOW TO INSTALL ADD-ON</span>

# %%
from IPython.display import Image
Image(filename='s1.png')

# %%
from IPython.display import Image
Image(filename='s2.png')

# %%
from IPython.display import Image
Image(filename='s3.png')

# %%
from IPython.display import Image
Image(filename='s4.png')

# %%
from IPython.display import Image
Image(filename='s5.png')

# %% [markdown]
# <span style="font-family: 'calibri' ; font-weight: bold; font-size: 24pt;">2.CREATE AN OPENAI API KEY</span>

# %%
from IPython.display import Image
Image(filename='s6.png')

# %%
from IPython.display import Image
Image(filename='s7.png')

# %%
from IPython.display import Image
Image(filename='Screenshot 2023-07-13 180514.png')

# %%
from IPython.display import Image
Image(filename='Screenshot 2023-07-13 180536.png')

# %%
from IPython.display import Image
Image(filename='Screenshot 2023-07-13 180628.png')

# %%
from IPython.display import Image
Image(filename='Screenshot 2023-07-13 180644.png')

# %%
from IPython.display import Image
Image(filename='Screenshot 2023-07-13 180709.png')

# %% [markdown]
# <span style="font-family: 'calibri' ; font-weight: bold; font-size: 24pt;">TOP 15 ACTIVITIES</span>.

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">1. Data Entry Automation:</span><span style="font-family: Calibri; font-size: 18pt;"> Use ChatGPT to take user inputs and directly update or append data to Google Sheets, reducing manual data entry.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">2. Dynamic Dashboards:</span><span style="font-family: Calibri; font-size: 18pt;">Create interactive dashboards by fetching data from Google Sheets and presenting it dynamically through ChatGPT conversations.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">3. Data Analysis:</span> <span style="font-family: Calibri; font-size: 18pt;">Perform data analysis tasks within the ChatGPT interface by querying data in Google Sheets and generating insights.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">4. Task Management:</span> <span style="font-family: Calibri; font-size: 18pt;">Use ChatGPT to manage tasks, deadlines, and updates, with all the data synchronized in Google Sheets.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">5. Language Translation: </span><span style="font-family: Calibri; font-size: 18pt;">Integrate translation capabilities with ChatGPT to translate text in Google Sheets, enabling multilingual data processing.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">6. Expense Tracking:</span><span style="font-family: Calibri; font-size: 18pt;"> Allow users to input expenses through ChatGPT, and automatically update and calculate expenses in Google Sheets.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">7. Budget Planning:</span><span style="font-family: Calibri; font-size: 18pt;"> Implement budget planning and tracking using ChatGPT, with data reflecting in Google Sheets in real-time.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">8. Inventory Management: </span><span style="font-family: Calibri; font-size: 18pt;"> Update and manage inventory data through ChatGPT, with changes immediately reflected in the Google Sheets inventory database.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">9. Feedback Collection:</span><span style="font-family: Calibri; font-size: 18pt;"> Gather feedback from users via ChatGPT and store it in Google Sheets for analysis and future reference.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">10. Project Status Updates: </span><span style="font-family: Calibri; font-size: 18pt;"> Allow team members to update project statuses through ChatGPT, which automatically updates a Google Sheets-based project tracker.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">11. Automated Reports:</span><span style="font-family: Calibri; font-size: 18pt;">  Generate automated reports using ChatGPT, pulling data from Google Sheets and presenting it in a readable format.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">12. Customer Support: </span><span style="font-family: Calibri; font-size: 18pt;">Provide instant responses to common queries using ChatGPT, which can access FAQs stored in a Google Sheet.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">13. Survey Conducting: </span><span style="font-family: Calibri; font-size: 18pt;">Create and conduct surveys through ChatGPT, with responses stored in Google Sheets for analysis.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">14. Content Generation:</span><span style="font-family: Calibri; font-size: 18pt;">  Use Google Sheets as a backend to store input data for ChatGPT to generate content based on predefined templates.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-weight: bold ; font-size: 18pt;">15. Appointment Scheduling: </span><span style="font-family: Calibri; font-size: 18pt;">Use ChatGPT to manage appointment bookings and synchronize them with a shared Google Calendar or Google Sheets.</span>

# %% [markdown]
# <span style="font-family: Calibri; font-size: 18pt;">By integrating ChatGPT with Google Sheets, you can automate various tasks, streamline workflows, and leverage the power of AI language capabilities to enhance user experiences and productivity. The possibilities are vast, and you can tailor the integration to suit your specific needs and use cases.</span>
